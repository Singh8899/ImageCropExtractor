# %% [markdown]
# # REQUIREMENTS

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # PULL DATASET FROM FIREBASE

# %%
# !python download_photo.py

# %% [markdown]
# # GENERATE DATASET METADATA

# %%
# !python dataset_generator.py

# %% [markdown]
# # TRAIN

# %%
# !python fine_tune_unsloath.py -o run/train1 -t hf_RtufltPHWQNCRwpenINqeqyYaYkFEjBAUFY
