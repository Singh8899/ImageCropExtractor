# %% [markdown]
# # REQUIREMENTS

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # GENERATE DATASET METADATA

# %%
# !python dataset_generator.py
# Out:
# Dataset with 3001 entries has been written to /workspace/ImageCropExtractor/dataset/dataset.json

# %% [markdown]
# # TRAIN

# %%
# !python fine_tune_unsloath.py

# %% [markdown]
# # UPLOAD

# %%
# !python upload_model.py -o "gmanuzz/diego_1" -t "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"
